# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0.001, 1, 1000)
len(x)
# Out:
# 1000

# %%
# y10 = np.log10(x)
y2 = np.log2(x)
H2 = x*y2
plt.plot(x, H2, 'r--', x, y2,'b', alpha = 0.5)

# %%
H2.sum()
# Out:
# -360.6725708633647
